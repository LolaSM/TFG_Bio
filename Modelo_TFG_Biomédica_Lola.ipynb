# %% [markdown]
# <a href="https://colab.research.google.com/github/LolaSM/TFG_Bio/blob/main/Modelo_TFG_Biom%C3%A9dica_Lola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load and Visualization of Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load the patients data that includes a vector per patient with statistics information: mean, desviation, kurtosis, skewness

# %%
url = 'https://raw.githubusercontent.com/LolaSM/TFG_Bio/refs/heads/main/tablaVectores_AB.csv'
patients_vector = pd.read_csv(url)

# %%
patients_vector.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   patient    87 non-null     int64
#  1   group      87 non-null     object
#  2   mediaPosX  87 non-null     float64
#  3   mediaPosY  87 non-null     float64
#  4   mediaPosZ  87 non-null     float64
#  5   mediaAngX  87 non-null     float64
#  6   mediaAngY  87 non-null     float64
#  7   mediaAngZ  87 non-null     float64
#  8   stdPosX    87 non-null     float64
#  9   stdPosY    87 non-null     float64
#  10  stdPosZ    87 non-null     float64
#  11  stdAngX    87 non-null     float64
#  12  stdAngY    87 non-null     float64
#  13  stdAngZ    87 non-null     float64
#  14  kurPosX    87 non-null     float64
#  15  kurPosY    87 non-null     float64
#  16  kurPosZ    87 non-null     float64
#  17  kurAngX    87 non-null     float64
#  18  kurAngY    87 non-null     float64
#  19  kurAngZ    87 non-null     float64
#  20  skwPosX    87 non-null     float64
#  21  skwPosY    87 non-null     float64
#  22  skwPosZ    87 non-null     float64
#  23  skwAngX    87 non-null     float64
#  24  skwAngY    87 non-null     float64
#  25  skwAngZ    87 non-null     float64
# dtypes: float64(24), int64(1), object(1)
# memory usage: 17.8+ KB

# %% [markdown]
# Each group (A:pain-free, B:pain-affected) will be represented by an integer

# %%
from sklearn.preprocessing import LabelEncoder

# Encode labels
le = LabelEncoder()
patients_vector['group'] = le.fit_transform(patients_vector['group'])

patients_vector.info(())

patients_vector['group'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   patient    87 non-null     int64
#  1   group      87 non-null     int64
#  2   mediaPosX  87 non-null     float64
#  3   mediaPosY  87 non-null     float64
#  4   mediaPosZ  87 non-null     float64
#  5   mediaAngX  87 non-null     float64
#  6   mediaAngY  87 non-null     float64
#  7   mediaAngZ  87 non-null     float64
#  8   stdPosX    87 non-null     float64
#  9   stdPosY    87 non-null     float64
#  10  stdPosZ    87 non-null     float64
#  11  stdAngX    87 non-null     float64
#  12  stdAngY    87 non-null     float64
#  13  stdAngZ    87 non-null     float64
#  14  kurPosX    87 non-null     float64
#  15  kurPosY    87 non-null     float64
#  16  kurPosZ    87 non-null     float64
#  17  kurAngX    87 non-null     float64
#  18  kurAngY    87 non-null     float64
#  19  kurAngZ    87 non-null     float64
#  20  skwPosX    87 non-null     float64
#  21  skwPosY    87 non-null     float64
#  22  skwPosZ    87 non-null     float64
#  23  skwAngX    87 non-null     float64
#  24  skwAngY    87 non-null     float64
#  25  skwAngZ    87 non-null     float64
# dtypes: float64(24), int64(2)
# memory usage: 17.8 KB
# group
# 1    44
# 0    43
# Name: count, dtype: int64

# %% [markdown]
# Calculate some statistics on the numerical attributes of the data set

# %%
patients_vector.describe()
# Out:
#          patient      group  mediaPosX  mediaPosY  mediaPosZ   mediaAngX  \
# count  87.000000  87.000000  87.000000  87.000000  87.000000   87.000000
# mean   44.000000   0.505747  -0.059953   0.080609  -0.135528   21.777296
# std    25.258662   0.502865   0.174426   0.109699   0.152778   46.915462
# min     1.000000   0.000000  -0.463461  -0.144969  -0.436056 -133.670906
# 25%    22.500000   0.000000  -0.196121   0.010847  -0.243030    2.623525
# 50%    44.000000   1.000000  -0.074201   0.050149  -0.151864   18.232636
# 75%    65.500000   1.000000   0.053279   0.130927  -0.061935   38.142684
# max    87.000000   1.000000   0.341293   0.510772   0.385731  130.979802
#
#        mediaAngY  mediaAngZ    stdPosX    stdPosY  ...    kurPosZ    kurAngX  \
# count  87.000000  87.000000  87.000000  87.000000  ...  87.000000  87.000000
# mean    9.043654  11.465555   0.305585   0.187887  ...   3.491393   4.307341
# std    24.382973  20.315275   0.077002   0.046358  ...   1.045866   3.005738
# min   -70.171128 -47.237003   0.147905   0.085560  ...   2.070942   1.555174
# 25%     0.834989   2.123479   0.253375   0.157738  ...   2.744160   2.891825
# 50%    10.191215  13.058274   0.306114   0.182628  ...   3.361792   3.513997
# 75%    21.655418  25.723812   0.348789   0.209365  ...   3.995969   4.689182
# max    67.437859  46.631483   0.569281   0.328776  ...   7.118408  22.831450
#
#          kurAngY    kurAngZ    skwPosX    skwPosY    skwPosZ    skwAngX  \
# count  87.000000  87.000000  87.000000  87.000000  87.000000  87.000000
# mean    2.713298   3.423739  -0.381677  -2.181063   0.397489  -0.189472
# std     0.557159   1.786158   0.431402   0.564154   0.622969   0.921146
# min     1.317157   1.607631  -1.328179  -3.923716  -1.170286  -4.133688
# 25%     2.391104   2.254043  -0.678083  -2.482284  -0.060922  -0.545106
# 50%     2.666059   2.892106  -0.416408  -2.183506   0.534675  -0.265575
# 75%     3.042633   4.060614  -0.152781  -1.764591   0.820419   0.064085
# max     4.085656  11.032297   1.329843  -0.895513   1.604121   4.142505
#
#          skwAngY    skwAngZ
# count  87.000000  87.000000
# mean   -0.217434  -0.133521
# std     0.457781   0.498549
# min    -1.042539  -1.271211
# 25%    -0.513255  -0.495290
# 50%    -0.256709  -0.196858
# 75%    -0.005930   0.145628
# max     1.292476   1.979461
#
# [8 rows x 26 columns]

# %% [markdown]
# # Feature Selection
